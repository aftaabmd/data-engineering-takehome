# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Jan  8 11:42:14 2023

@author: aftaabmohammed
"""


import pandas
from matplotlib import pyplot as plt


data_cus=pandas.read_csv("sample_data/Customer.txt", sep="|", header=None, names=["Column1", "Column2","Column3", "Column4"])
data_cus_ex=pandas.read_csv("sample_data/Customer_Extended.txt", sep="|", header=None)
data_refund=pandas.read_csv("sample_data/Refund.txt", sep="|", header=None)
data_sales=pandas.read_csv("sample_data/Sales.txt", sep="|", header=None, names=["Column1", "Column2","Column3", "Column4","Column5","Column6"])
data_product=pandas.read_csv("sample_data/Product.txt", sep="|", header=None, names=["Column1", "Column2","Column3", "Column4","Column5"])

# %%
data_cus.head()
# Out:
#    Column1   Column2  Column3      Column4
# 0   815001     LYNCH  JACKSON  14157317623
# 1   815002      MOSS   FIELDS  14156874907
# 2   815003    MCCALL    BOYLE  14151620323
# 3   815004  DELACRUZ   MADDEN  14151364678
# 4   815005      RUIZ     CAIN  14155195074

# %%
data_product.head()
# Out:
#    Column1         Column2 Column3          Column4 Column5
# 0     1111          Phone     P105  Product Desc 18    $599
# 1     1112         Laptop     P105  Product Desc 20    $999
# 2     1113        Desktop     P106  Product Desc 22   $1449
# 3     1114       Harddisk     P102   Product Desc 3     $99
# 4     1115  GamingConsole     P103  Product Desc 12    $249

# %%
data_sales.head()
# Out:
#    Column1  Column2  Column3              Column4 Column5  Column6
# 0   115001   815159     1122  08/12/2012 17:45:57     $99        1
# 1   115002   815457     1127  11/25/2012 09:39:00     $76        4
# 2   115003   815406     1131  02/28/2012 06:13:05    $438        2
# 3   115004   815433     1130  08/14/2012 17:29:20   $1047        3
# 4   115005   815159     1116  02/11/2013 03:25:52   $2796        4

# %%
data_sales_groupby = data_sales.groupby("Column3")["Column5"].count().to_frame(name = 'count').reset_index()

data_prod_2 = data_product.join(data_sales_groupby["count"])

# %%
from matplotlib import pyplot as plt

# %%
data_prod_2.plot(x="Column2", y=["count"], kind="bar", stacked = True)
# Out:
# <AxesSubplot:xlabel='Column2'>

# %%
data_prod_2
# Out:
#     Column1               Column2 Column3          Column4 Column5  count
# 0      1111                Phone     P105  Product Desc 18    $599    184
# 1      1112               Laptop     P105  Product Desc 20    $999    219
# 2      1113              Desktop     P106  Product Desc 22   $1449    218
# 3      1114             Harddisk     P102   Product Desc 3     $99    246
# 4      1115        GamingConsole     P103  Product Desc 12    $249    225
# 5      1116               Tablet     P105  Product Desc 19    $699    249
# 6      1117                Watch     P104  Product Desc 16    $399    236
# 7      1118               Camera     P104  Product Desc 17    $499    227
# 8      1119            Camcorder     P103  Product Desc 13    $299    224
# 9      1120              Printer     P104  Product Desc 14    $349    252
# 10     1121              Monitor     P103   Product Desc 7    $149    238
# 11     1122        Kids's tablet     P102   Product Desc 4     $99    200
# 12     1123      VR Play Station     P103   Product Desc 9    $199    234
# 13     1124                Drone     P102   Product Desc 2     $89    240
# 14     1125             Keyboard     P102   Product Desc 5     $99    228
# 15     1126          Magic Mouse     P102   Product Desc 6     $99    222
# 16     1127          Memory card     P101   Product Desc 1     $19    227
# 17     1128              Speaker     P103   Product Desc 8    $149    232
# 18     1129  Home Automation Kit     P105  Product Desc 21    $999    220
# 19     1130         Baby Monitor     P104  Product Desc 15    $349    215
# 20     1131      Doorbell Carema     P103  Product Desc 11    $219    209
# 21     1132        Car Connector     P103  Product Desc 10    $217    254

# %%
data_sales["Column4"] = pandas.to_datetime(data_sales["Column4"])

# %%
mask = (df['Column'] > ) & (df['date'] <= end_date)
# Out:
# 0      2012-08-12 17:45:57
# 1      2012-11-25 09:39:00
# 2      2012-02-28 06:13:05
# 3      2012-08-14 17:29:20
# 4      2013-02-11 03:25:52
#                ...
# 4994   2012-05-10 06:21:49
# 4995   2012-05-24 00:53:51
# 4996   2013-01-30 14:24:11
# 4997   2012-09-03 08:42:20
# 4998   2012-09-03 21:43:19
# Name: Column4, Length: 4999, dtype: datetime64[ns]

# %%
data_sales["Column3"].unique()
# Out:
# array([1122, 1127, 1131, 1130, 1116, 1125, 1129, 1111, 1119, 1126, 1123,
#        1124, 1115, 1121, 1112, 1118, 1132, 1114, 1113, 1117, 1128, 1120])

# %%
data_prod_2["Column1"].unique()
# Out:
# array([1111, 1112, 1113, 1114, 1115, 1116, 1117, 1118, 1119, 1120, 1121,
#        1122, 1123, 1124, 1125, 1126, 1127, 1128, 1129, 1130, 1131, 1132])

# %%
data_cus_ex.head()
# Out:
#        0           1        2            3            4       5   \
# 0  815001       CASEY   REEVES  14157280534  14158398924    Male
# 1  815002     HIGGINS     CRUZ  14158042860  14151634567    Male
# 2  815003       DRAKE  SANDERS  14155307883  14154734920    Male
# 3  815004  PENNINGTON  WHITNEY  14152416539  14159316678  Female
# 4  815005     MCGUIRE    CAREY  14153240238  14154878197    Male
#
#                    6                 7   8    9   ...                    16  \
# 0     917 MALONE Blvd           WINTERS  KS  USA  ...  1433 FITZPATRICK St.
# 1   1156 DRAKE Street  WESTLAKE VILLAGE  ID  USA  ...     5080 SUMMERS Blvd
# 2   2363 MCKEE Street      REDWOOD CITY  NY  USA  ...       4776 WATTS Blvd
# 3       2866 LUTZ St.        MINNEAPDIS  WA  USA  ...      4130 GRIMES Blvd
# 4  925 FERRELL Street      HILLSBOROUGH  ID  USA  ...      2992 CLAY Street
#
#            17        18   19     20                      21  \
# 0   DEERFIELD  Delaware  USA  91317       AYALA@hotmail.com
# 1   SAN RAMON        KS  USA  93171  STEPHENSON@hotmail.com
# 2   SANLENDRO        WA  USA  95691    SANTIAGO@hotmail.com
# 3  SANTA ROSA        KS  USA  93383     BONILLA@hotmail.com
# 4  EL CERRITO        TX  USA  90168  WILLIAMSON@hotmail.com
#
#                      22                     23                     24  \
# 0  MCCULLOUGH@gmail.com   CHAMBERS@twitter.com  CALDERON@facebook.com
# 1      BENSON@gmail.com      OCHOA@twitter.com      FREY@facebook.com
# 2        BEAN@gmail.com   MCINTYRE@twitter.com   STEVENS@facebook.com
# 3      ROGERS@gmail.com     HANSON@twitter.com    CROSBY@facebook.com
# 4      HOOPER@gmail.com  HENDERSON@twitter.com    STUART@facebook.com
#
#                       25
# 0     SCOTT@linkedin.com
# 1   NAVARRO@linkedin.com
# 2  MCDOWELL@linkedin.com
# 3   GILBERT@linkedin.com
# 4     NOLAN@linkedin.com
#
# [5 rows x 26 columns]
